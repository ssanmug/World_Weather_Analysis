# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime 
import requests

# %%
# Import the API key

from config_challenge import challenge_api_key

# %%
# Create 2000 random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + challenge_api_key

# %%
# Create an empty list to hold the weather data.
city_challenge_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_challenge_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Current Description": city_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | novyy urengoy
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | wewak
# Processing Record 4 of Set 1 | faanui
# Processing Record 5 of Set 1 | dunedin
# Processing Record 6 of Set 1 | verkhoshizhemye
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | luderitz
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | norman wells
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | la ronge
# Processing Record 14 of Set 1 | humaita
# Processing Record 15 of Set 1 | sembe
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | sibu
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 1 | maghama
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_challenge_data_df = pd.DataFrame(city_challenge_data)
city_challenge_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Novyy Urengoy  66.0833   76.6333     37.78        94          92
# 1   Ribeira Grande  38.5167  -28.7000     72.30        84          95
# 2            Wewak  -3.5534  143.6268     78.73        84          73
# 3           Faanui -16.4833 -151.7500     79.05        70           4
# 4          Dunedin -45.8742  170.5036     48.79        61          95
# 5  Verkhoshizhemye  58.0110   49.1038     39.60        94         100
# 6             Lebu -37.6167  -73.6500     50.13        90           0
# 7         Luderitz -26.6481   15.1594     61.70        41          15
# 8         Cidreira -30.1811  -50.2056     59.99        66          98
# 9     Norman Wells  65.2820 -126.8329     55.33        55           7
#
#    Wind Speed Country Current Description
# 0       14.47      RU     overcast clouds
# 1        4.72      PT     overcast clouds
# 2        5.01      PG       broken clouds
# ...

# %%
# Confirm row count > 500 cities
len(city_challenge_data_df)
# Out:
# 715

# %%
# Reorder columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_challenge_data_df = city_challenge_data_df[new_column_order]
city_challenge_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0       Novyy Urengoy      RU  66.0833   76.6333     37.78        94
# 1      Ribeira Grande      PT  38.5167  -28.7000     72.30        84
# 2               Wewak      PG  -3.5534  143.6268     78.73        84
# 3              Faanui      PF -16.4833 -151.7500     79.05        70
# 4             Dunedin      NZ -45.8742  170.5036     48.79        61
# ..                ...     ...      ...       ...       ...       ...
# 710       Kattivakkam      IN  13.2167   80.3167     84.29        74
# 711          Vilyuysk      RU  63.7553  121.6247     41.36        67
# 712           Douglas      US  41.3000  -96.1670     90.99        44
# 713         Tazovskiy      RU  67.4667   78.7000     38.88        93
# 714  Kuala Terengganu      MY   5.3302  103.1408     76.80        89
#
#      Cloudiness  Wind Speed Current Description
# 0            92       14.47     overcast clouds
# ...

# %%
# Create the output file (CSV).

output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.

city_challenge_data_df.to_csv(output_data_file, index_label="City_ID")
